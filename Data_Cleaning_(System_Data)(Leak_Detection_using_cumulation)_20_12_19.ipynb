# %% [markdown]
# <a href="https://colab.research.google.com/github/supermansam/EqWATER/blob/master/Data_Cleaning_(System_Data)(Leak_Detection_using_cumulation)_20_12_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing drive to access data
from google.colab import drive

# %%
#Providing access
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from plotnine import *
from pandas import *

# %%
#Accessing intermittent files, change whenever new files are needed
E1 = pd.read_csv("/content/drive/My Drive/RA_IISc/Leak_Detection/Intermittent-Experiment/5.12.19intermittent12.35.csv",sep = ',|\t|\s+')
E2 = pd.read_csv("/content/drive/My Drive/RA_IISc/Leak_Detection/Intermittent-Experiment/6.12.19intermittent14.25.csv",sep = ',|\t|\s+')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
#Cleaning data
#E1.dropna(axis = 1)
#Dropped Unnamed axes, use this code directly to clean the data
i=4
while(i<38):
  E1 = E1.drop(['Unnamed: '+str(i), 'Unnamed: '+str(i+1)], axis=1)
  i+=3
E1 = E1.drop('Unnamed: 2', axis=1)
E1.columns = ["Date", "Time", "F1", "F2","F3","F4","F5","F6","F7","Top Tank","P1","P2","P3","Unknown"]
#E1.head()

# %%
#####################################
#E1.columns
#E1.columns = ["Date", "Time", "F1", "F2","F3","F4","F5","F6","F7","Top Tank","P1","P2","P3","Unknown"]
#E1.head()
#####################################
## For E2
i=4
while(i<38):
  E2 = E2.drop(['Unnamed: '+str(i), 'Unnamed: '+str(i+1)], axis=1)
  i+=3
E2 = E2.drop('Unnamed: 2', axis=1)
E2.columns = ["Date", "Time", "F1", "F2","F3","F4","F5","F6","F7","Top Tank","P1","P2","P3","Unknown"]
#E2.head()

# %%
#Attempt at using R functions
# !pip install rpy2

# %%
#Initial changes
from rpy2.robjects.packages import importr
import rpy2.robjects as ro
from pandas import *
#Deprecated
#import pandas.rpy.common as com

# %%
#ro.r('x=c()')
#ro.r('x[1]=10')
#ro.r('x[2]=13')
#print(ro.r('x'))
#type(ro.r('x'))
############# Using R directly for primary analysis
#E1.head()
#E2.head()
# Out:
#          Date      Time        F1  ...        P2        P3    Unknown
# 0  06-12-2019  14:25:20  0.001072  ...  4.712686  4.866072 -39.085612
# 1  06-12-2019  14:25:21  0.001229  ...  5.024973  4.420450 -37.580822
# 2  06-12-2019  14:25:22  0.001072  ...  4.279094  4.240998 -38.510664
# 3  06-12-2019  14:25:23  0.001054  ...  5.640022  4.890634 -38.337728
# 4  06-12-2019  14:25:24  0.000890  ...  4.794893  4.064053 -38.366802
#
# [5 rows x 14 columns]

# %%
#export_csv = E1.to_csv (r'/content/drive/My Drive/RA_IISc/Leak_Detection/Intermittent-Experiment/E1(05-12-2019_12:30).csv', index = None, header=True)
#export_csv = E2.to_csv (r'/content/drive/My Drive/RA_IISc/Leak_Detection/Intermittent-Experiment/E2(06-12-2019_14:25).csv', index = None, header=True)
#E2_Flow = E2[['F2','F5','F6']]
#E1_Flow.head()
#fig = E2_Flow.plot(figsize=(25,15), grid=True)
